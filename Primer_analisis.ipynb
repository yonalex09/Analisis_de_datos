# %% [markdown]
# <a href="https://colab.research.google.com/github/yonalex09/Analisis_de_datos/blob/main/Primer_analisis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import statsmodels.api as sm

url = "https://raw.githubusercontent.com/yonalex09/Analisis_de_datos/main/Sample%20-%20Superstore.csv"
df = pd.read_csv(url,encoding='ISO-8859-1')

print("\n\nAqui realizamos una matrix de correlacion\n\n")
corr = df.set_index('Category').corr()
sm.graphics.plot_corr(corr, xnames=list(corr.columns))
plt.show()
# Out:
# Aqui realizamos un diagrama de correlacion
