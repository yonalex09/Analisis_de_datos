# %% [markdown]
# <a href="https://colab.research.google.com/github/yonalex09/Analisis_de_datos/blob/main/Segundo_analisis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

url = "https://raw.githubusercontent.com/yonalex09/Analisis_de_datos/main/Sample%20-%20Superstore.csv"
df = pd.read_csv(url,encoding='ISO-8859-1')


plt.figure(figsize=(30,10))
plt.scatter(df["City"], df["Sales"])
plt.xlabel("Ciudades")
plt.ylabel("Ventas")
plt.title("Diagrama de dispersión")
plt.xticks(rotation=45)
plt.show()
